# %% [markdown]
# <a href="https://colab.research.google.com/github/Kusalb/Abilis/blob/master/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from sklearn.metrics import mean_absolute_error
from torch.utils.data import DataLoader
from sklearn.metrics import r2_score

# %%
dataset = pd.read_csv("google.csv")
dataset
# Out:
#             Date         High          Low         Open        Close  \
# 0     2004-08-19    51.835709    47.800831    49.813290    49.982655
# 1     2004-08-20    54.336334    50.062355    50.316402    53.952770
# 2     2004-08-23    56.528118    54.321388    55.168217    54.495735
# 3     2004-08-24    55.591629    51.591621    55.412300    52.239197
# 4     2004-08-25    53.798351    51.746044    52.284027    52.802086
# ...          ...          ...          ...          ...          ...
# 4312  2021-10-05  2747.239990  2680.000000  2680.000000  2723.540039
# 4313  2021-10-06  2757.040039  2689.729980  2692.510010  2747.080078
# 4314  2021-10-07  2803.089111  2771.260010  2777.260010  2783.709961
# 4315  2021-10-08  2806.340088  2788.586914  2798.120117  2801.120117
# 4316  2021-10-11  2815.272949  2776.129883  2796.000000  2776.949951
#
#           Volume    Adj Close
# 0     44871361.0    49.982655
# 1     22942874.0    53.952770
# 2     18342897.0    54.495735
# 3     15319808.0    52.239197
# 4      9232276.0    52.802086
# ...          ...          ...
# 4312   1206300.0  2723.540039
# 4313    988200.0  2747.080078
# 4314    912500.0  2783.709961
# 4315    946200.0  2801.120117
# 4316    828700.0  2776.949951
#
# [4317 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4317 entries, 0 to 4316
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4317 non-null   object
#  1   High       4317 non-null   float64
#  2   Low        4317 non-null   float64
#  3   Open       4317 non-null   float64
#  4   Close      4317 non-null   float64
#  5   Volume     4317 non-null   float64
#  6   Adj Close  4317 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 236.2+ KB

# %%
dataset.head()
# Out:
#          Date       High        Low       Open      Close      Volume  \
# 0  2004-08-19  51.835709  47.800831  49.813290  49.982655  44871361.0
# 1  2004-08-20  54.336334  50.062355  50.316402  53.952770  22942874.0
# 2  2004-08-23  56.528118  54.321388  55.168217  54.495735  18342897.0
# 3  2004-08-24  55.591629  51.591621  55.412300  52.239197  15319808.0
# 4  2004-08-25  53.798351  51.746044  52.284027  52.802086   9232276.0
#
#    Adj Close
# 0  49.982655
# 1  53.952770
# 2  54.495735
# 3  52.239197
# 4  52.802086

# %%
dataset.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  4317.000000  4317.000000  4317.000000  4317.000000  4.317000e+03
# mean    639.682936   627.615621   633.603748   633.852357  6.523837e+06
# std     561.783142   552.069438   556.527532   557.255541  7.830526e+06
# min      50.680038    47.800831    49.409801    49.818268  7.922000e+03
# 25%     247.507278   241.469910   244.832306   244.334183  1.593563e+06
# 50%     401.988251   395.168823   399.004425   398.561096  3.851583e+06
# 75%     933.440002   923.030029   929.059998   928.799988  8.268878e+06
# max    2936.409912  2912.290039  2918.989990  2916.840088  8.254163e+07
#
#          Adj Close
# count  4317.000000
# mean    633.852357
# std     557.255541
# min      49.818268
# 25%     244.334183
# 50%     398.561096
# 75%     928.799988
# max    2916.840088

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'])
plt.plot(dataset['Date'], dataset['Close'])

# %%
dataset.head()
# Out:
#         Date       High        Low       Open      Close      Volume  \
# 0 2004-08-19  51.835709  47.800831  49.813290  49.982655  44871361.0
# 1 2004-08-20  54.336334  50.062355  50.316402  53.952770  22942874.0
# 2 2004-08-23  56.528118  54.321388  55.168217  54.495735  18342897.0
# 3 2004-08-24  55.591629  51.591621  55.412300  52.239197  15319808.0
# 4 2004-08-25  53.798351  51.746044  52.284027  52.802086   9232276.0
#
#    Adj Close
# 0  49.982655
# 1  53.952770
# 2  54.495735
# 3  52.239197
# 4  52.802086

# %%
from copy import deepcopy as dc

def prepare_dataframe_for_lstm(df, n_steps):
    df = dc(df)

    df.set_index('Date', inplace=True)

    for i in range(1, n_steps + 1):
        df[f'Close(t-{i})'] = df['Close'].shift(i)
    df.dropna(inplace=True)
    return df[['Close'] + [f'Close(t-{i})' for i in range(1, n_steps + 1)]]

lookback = 7
shifted_df = prepare_dataframe_for_lstm(dataset, lookback)
print(shifted_df)
# Out:
#                   Close   Close(t-1)   Close(t-2)   Close(t-3)   Close(t-4)  \
# Date
# 2004-08-30    50.814533    52.876804    53.753517    52.802086    52.239197
# 2004-08-31    50.993862    50.814533    52.876804    53.753517    52.802086
# 2004-09-01    49.937820    50.993862    50.814533    52.876804    53.753517
# 2004-09-02    50.565468    49.937820    50.993862    50.814533    52.876804
# 2004-09-03    49.818268    50.565468    49.937820    50.993862    50.814533
# ...                 ...          ...          ...          ...          ...
# 2021-10-05  2723.540039  2675.300049  2729.250000  2665.310059  2690.419922
# 2021-10-06  2747.080078  2723.540039  2675.300049  2729.250000  2665.310059
# 2021-10-07  2783.709961  2747.080078  2723.540039  2675.300049  2729.250000
# 2021-10-08  2801.120117  2783.709961  2747.080078  2723.540039  2675.300049
# 2021-10-11  2776.949951  2801.120117  2783.709961  2747.080078  2723.540039
#
#              Close(t-5)   Close(t-6)   Close(t-7)
# Date
# 2004-08-30    54.495735    53.952770    49.982655
# 2004-08-31    52.239197    54.495735    53.952770
# 2004-09-01    52.802086    52.239197    54.495735
# 2004-09-02    53.753517    52.802086    52.239197
# 2004-09-03    52.876804    53.753517    52.802086
# ...                 ...          ...          ...
# 2021-10-05  2723.679932  2830.020020  2852.659912
# 2021-10-06  2690.419922  2723.679932  2830.020020
# 2021-10-07  2665.310059  2690.419922  2723.679932
# 2021-10-08  2729.250000  2665.310059  2690.419922
# 2021-10-11  2675.300049  2729.250000  2665.310059
#
# [4310 rows x 8 columns]

# %%
shifted_df_as_np = shifted_df.to_numpy()

shifted_df_as_np
# Out:
# array([[  50.81453323,   52.87680435,   53.75351715, ...,   54.49573517,
#           53.95277023,   49.98265457],
#        [  50.99386215,   50.81453323,   52.87680435, ...,   52.23919678,
#           54.49573517,   53.95277023],
#        [  49.93782043,   50.99386215,   50.81453323, ...,   52.80208588,
#           52.23919678,   54.49573517],
#        ...,
#        [2783.70996094, 2747.08007812, 2723.54003906, ..., 2665.31005859,
#         2690.41992188, 2723.67993164],
#        [2801.12011719, 2783.70996094, 2747.08007812, ..., 2729.25      ,
#         2665.31005859, 2690.41992188],
#        [2776.94995117, 2801.12011719, 2783.70996094, ..., 2675.30004883,
#         2729.25      , 2665.31005859]])

# %%
shifted_df_as_np.shape
# Out:
# (4310, 8)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
shifted_df_as_np = scaler.fit_transform(shifted_df_as_np)

shifted_df_as_np
# Out:
# array([[-0.99930502, -0.9978664 , -0.99725482, ..., -0.99673705,
#         -0.99711582, -0.99988533],
#        [-0.99917992, -0.99930502, -0.9978664 , ..., -0.99831119,
#         -0.99673705, -0.99711582],
#        [-0.9999166 , -0.99917992, -0.99930502, ..., -0.99791852,
#         -0.99831119, -0.99673705],
#        ...,
#        [ 0.90713002,  0.88157746,  0.86515621, ...,  0.82453567,
#          0.84205201,  0.86525379],
#        [ 0.91927514,  0.90713002,  0.88157746, ...,  0.86913941,
#          0.82453567,  0.84205201],
#        [ 0.90241432,  0.91927514,  0.90713002, ...,  0.83150457,
#          0.86913941,  0.82453567]])

# %%
X = shifted_df_as_np[:, 1:]
y = shifted_df_as_np[:, 0]

X.shape, y.shape
# Out:
# ((4310, 7), (4310,))

# %%
X = dc(np.flip(X, axis=1))
X
# Out:
# array([[-0.99988533, -0.99711582, -0.99673705, ..., -0.99791852,
#         -0.99725482, -0.9978664 ],
#        [-0.99711582, -0.99673705, -0.99831119, ..., -0.99725482,
#         -0.9978664 , -0.99930502],
#        [-0.99673705, -0.99831119, -0.99791852, ..., -0.9978664 ,
#         -0.99930502, -0.99917992],
#        ...,
#        [ 0.86525379,  0.84205201,  0.82453567, ...,  0.83150457,
#          0.86515621,  0.88157746],
#        [ 0.84205201,  0.82453567,  0.86913941, ...,  0.86515621,
#          0.88157746,  0.90713002],
#        [ 0.82453567,  0.86913941,  0.83150457, ...,  0.88157746,
#          0.90713002,  0.91927514]])

# %%
split_index = int(len(X) * 0.95)

split_index
# Out:
# 4094

# %%
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4094, 7), (216, 7), (4094,), (216,))

# %%
X_train = X_train.reshape((-1, lookback, 1))
X_test = X_test.reshape((-1, lookback, 1))

y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4094, 7, 1), (216, 7, 1), (4094, 1), (216, 1))

# %%
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([4094, 7, 1]),
#  torch.Size([216, 7, 1]),
#  torch.Size([4094, 1]),
#  torch.Size([216, 1]))

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %%
train_dataset

# %%
batch_size = 16

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([16, 7, 1]) torch.Size([16, 1])

# %%
class RNN(nn.Module):
  def __init__(self, input_size, hidden_size,num_layers):
    super(RNN,self).__init__()
    self.num_layers = num_layers
    self.hidden_size = hidden_size
    self.rnn = nn.RNN(input_size,hidden_size,num_layers, batch_first = True)
    self.fc = nn.Linear(hidden_size,1)
  def forward(self,x):
    h0 = torch.zeros(self.num_layers,x.size(0),self.hidden_size).to(device)
    out, _ = self.rnn(x,h0)
    out = out[:, -1,:]
    out = self.fc(out)
    return out

# %%
model = RNN(1, 50, 1)
model.to(device)
model
# Out:
# RNN(
#   (rnn): RNN(1, 50, batch_first=True)
#   (fc): Linear(in_features=50, out_features=1, bias=True)
# )

# %%
class StockPredictionTrainer:
    def __init__(self, model, train_loader, test_loader, num_epochs=10, learning_rate=0.001):
        self.model = model
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.num_epochs = num_epochs
        self.learning_rate = learning_rate
        self.loss_function = nn.MSELoss()
        self.optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        self.gradients = []
        self.mean_losses = []
        self.losses = []


    def run_training(self):
        for epoch in range(self.num_epochs):
            self.model.train(True)  # Set the model to training mode
            print(f'Epoch: {epoch + 1}')
            running_loss = 0.0
            gradients = []  # Store gradients for each epoch
            mean_losses =[]
            losses =[]
            for batch_index, batch in enumerate(self.train_loader):
                x_batch, y_batch = batch[0].to(device), batch[1].to(device)

                output = self.model(x_batch)
                loss = self.loss_function(output, y_batch)
                running_loss += loss.item()

                self.optimizer.zero_grad()
                loss.backward()
                losses.append(loss.item())
                # Store gradients for each parameter in the model
                sum_gradients = 0
                number_parameters = 0

                for layers in self.model.rnn.all_weights:
                    for weights in layers:
                        sum_gradients += weights.sum()
                        number_parameters += torch.numel(weights)

                mean_grad = sum_gradients / number_parameters
                self.gradients.append([mean_grad.detach().numpy()])


                self.optimizer.step()

                if batch_index % 100 == 99:  # print every 100 batches
                    avg_loss_across_batches = running_loss / 100
                    print('Batch {0}, Loss: {1:.3f}'.format(batch_index + 1, avg_loss_across_batches))
                    running_loss = 0.0
            print()


            # Validation after each epoch
            self.model.train(False)  # Set the model to evaluation mode
            running_loss = 0.0

            for batch_index, batch in enumerate(self.test_loader):
                x_batch, y_batch = batch[0].to(device), batch[1].to(device)

                with torch.no_grad():
                    output = self.model(x_batch)
                    loss = self.loss_function(output, y_batch)
                    running_loss += loss.item()

            avg_loss_across_batches = running_loss / len(self.test_loader)
            self.mean_losses.append(avg_loss_across_batches)
            self.losses.append(sum(losses)/len(losses))
            print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
            print('***************************************************')
            print()


    def calculate_mae(self, predictions, targets):
        return mean_absolute_error(targets, predictions)

    def calculate_and_print_mae(self, X_train, y_train, X_test, y_test):
        with torch.no_grad():
            predicted_train = self.model(X_train.to(device)).to('cpu').numpy()
            predicted_test = self.model(X_test.to(device)).detach().cpu().numpy().flatten()

        mae_train = self.calculate_mae(predicted_train, y_train.numpy())
        mae_test = self.calculate_mae(predicted_test, y_test.numpy())

        print(f'Mean Absolute Error in training: {mae_train}')
        print(f'Mean Absolute Error in testing: {mae_test}')

    def plot_predictions(self, X_train, y_train, X_test, y_test, lookback):
        with torch.no_grad():
            predicted_train = self.model(X_train.to(device)).to('cpu').numpy()
            predicted_test = self.model(X_test.to(device)).detach().cpu().numpy().flatten()

        train_predictions = dc(predicted_train[:, 0])
        test_predictions = dc(predicted_test)

        self.plot_results(y_train, train_predictions, "Training Set")
        self.plot_results(y_test, test_predictions, "Test Set")

    def plot_results(self, actual, predicted, title):
        dummies_actual = np.zeros((actual.shape[0], 1))
        dummies_actual[:, 0] = actual.flatten()
        actual_values = dc(dummies_actual[:, 0])

        dummies_predicted = np.zeros((predicted.shape[0], 1))
        dummies_predicted[:, 0] = predicted.flatten()
        predicted_values = dc(dummies_predicted[:, 0])

        plt.plot(actual_values, label='Actual Close')
        plt.plot(predicted_values, label='Predicted Close')
        plt.xlabel('Day')
        plt.ylabel('Close')
        plt.title(title)
        plt.legend()
        plt.show()


    def plot_gradients_losses(self):
        figure, axis = plt.subplots(1, 2,figsize=(15, 5))
        axis[0].plot(self.gradients)
        axis[0].set_title('Fit in training')
        axis[0].set_xlabel('Steps (Iterations)')
        axis[0].set_ylabel('Mean gradient value')
      # Plot validation vs. training loss
        axis[1].plot(self.mean_losses, label='Training Loss')
        axis[1].plot(self.losses, label='Validation Loss', color='orange')
        axis[1].set_title('Validation vs. Training Loss')
        axis[1].set_xlabel('Epochs')
        axis[1].set_ylabel('Loss value (mean)')
        axis[1].legend()

        plt.show()

# %%
learning_rate = 0.00001
num_epochs=10

# %%
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)

# %%
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.434
# Batch 200, Loss: 0.404
#
# Val Loss: 0.585
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.326
# Batch 200, Loss: 0.287
#
# Val Loss: 0.658
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.224
# Batch 200, Loss: 0.186
#
# Val Loss: 0.743
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.129
# Batch 200, Loss: 0.099
#
# Val Loss: 0.848
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.067
# Batch 200, Loss: 0.057
#
# Val Loss: 0.915
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.049
# Batch 200, Loss: 0.046
#
# Val Loss: 0.893
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.044
# Batch 200, Loss: 0.045
#
# Val Loss: 0.832
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.041
# Batch 200, Loss: 0.039
#
# Val Loss: 0.748
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.039
# Batch 200, Loss: 0.035
#
# Val Loss: 0.653
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.033
# Batch 200, Loss: 0.031
#
# Val Loss: 0.544
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.14120225608348846
# Mean Absolute Error in testing: 0.7187973260879517

# %% [markdown]
# Changing learning rate, learning_rate = 0.001

# %%
model = RNN(1, 50, 1)
model.to(device)
model
# Out:
# RNN(
#   (rnn): RNN(1, 50, batch_first=True)
#   (fc): Linear(in_features=50, out_features=1, bias=True)
# )

# %%
learning_rate = 0.001
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)

# %%
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.049
# Batch 200, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.021
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.007536322809755802
# Mean Absolute Error in testing: 0.08398737013339996

# %%
my_trainer.plot_gradients_losses()

# %% [markdown]
# Changing the number of layer to 3

# %%
model = RNN(1, 50, 3)
model.to(device)
model
# Out:
# RNN(
#   (rnn): RNN(1, 50, num_layers=3, batch_first=True)
#   (fc): Linear(in_features=50, out_features=1, bias=True)
# )

# %%
learning_rate = 0.001
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)

# %%
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.031
# Batch 200, Loss: 0.000
#
# Val Loss: 0.051
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.045
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.042
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.033
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.038
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.005681484937667847
# Mean Absolute Error in testing: 0.08647733181715012

# %% [markdown]
# Adding gradient clipping

# %%
class StockPredictionTrainer:
    def __init__(self, model, train_loader, test_loader, num_epochs=10, learning_rate=0.001):
        self.model = model
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.num_epochs = num_epochs
        self.learning_rate = learning_rate
        self.loss_function = nn.MSELoss()
        self.optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        self.gradients = []
        self.mean_losses = []
        self.losses = []


    def run_training(self):
        for epoch in range(self.num_epochs):
            self.model.train(True)  # Set the model to training mode
            print(f'Epoch: {epoch + 1}')
            running_loss = 0.0
            gradients = []  # Store gradients for each epoch
            mean_losses =[]
            losses =[]
            for batch_index, batch in enumerate(self.train_loader):
                x_batch, y_batch = batch[0].to(device), batch[1].to(device)

                output = self.model(x_batch)
                loss = self.loss_function(output, y_batch)
                running_loss += loss.item()

                self.optimizer.zero_grad()
                loss.backward()
                losses.append(loss.item())
                # torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.clipping)
                # Store gradients for each parameter in the model
                sum_gradients = 0
                number_parameters = 0

                for layers in self.model.rnn.all_weights:
                    for weights in layers:
                        sum_gradients += weights.sum()
                        number_parameters += torch.numel(weights)

                mean_grad = sum_gradients / number_parameters
                self.gradients.append([mean_grad.detach().numpy()])


                self.optimizer.step()

                if batch_index % 100 == 99:  # print every 100 batches
                    avg_loss_across_batches = running_loss / 100
                    print('Batch {0}, Loss: {1:.3f}'.format(batch_index + 1, avg_loss_across_batches))
                    running_loss = 0.0
            print()


            # Validation after each epoch
            self.model.train(False)  # Set the model to evaluation mode
            running_loss = 0.0

            for batch_index, batch in enumerate(self.test_loader):
                x_batch, y_batch = batch[0].to(device), batch[1].to(device)

                with torch.no_grad():
                    output = self.model(x_batch)
                    loss = self.loss_function(output, y_batch)
                    running_loss += loss.item()

            avg_loss_across_batches = running_loss / len(self.test_loader)
            self.mean_losses.append(avg_loss_across_batches)
            self.losses.append(sum(losses)/len(losses))
            print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
            print('***************************************************')
            print()


    def calculate_mae(self, predictions, targets):
        return mean_absolute_error(targets, predictions)

    def calculate_and_print_mae(self, X_train, y_train, X_test, y_test):
        with torch.no_grad():
            predicted_train = self.model(X_train.to(device)).to('cpu').numpy()
            predicted_test = self.model(X_test.to(device)).detach().cpu().numpy().flatten()

        mae_train = self.calculate_mae(predicted_train, y_train.numpy())
        mae_test = self.calculate_mae(predicted_test, y_test.numpy())

        print(f'Mean Absolute Error in training: {mae_train}')
        print(f'Mean Absolute Error in testing: {mae_test}')

    def plot_predictions(self, X_train, y_train, X_test, y_test, lookback):
        with torch.no_grad():
            predicted_train = self.model(X_train.to(device)).to('cpu').numpy()
            predicted_test = self.model(X_test.to(device)).detach().cpu().numpy().flatten()

        train_predictions = dc(predicted_train[:, 0])
        test_predictions = dc(predicted_test)

        self.plot_results(y_train, train_predictions, "Training Set")
        self.plot_results(y_test, test_predictions, "Test Set")

    def plot_results(self, actual, predicted, title):
        dummies_actual = np.zeros((actual.shape[0], 1))
        dummies_actual[:, 0] = actual.flatten()
        actual_values = dc(dummies_actual[:, 0])

        dummies_predicted = np.zeros((predicted.shape[0], 1))
        dummies_predicted[:, 0] = predicted.flatten()
        predicted_values = dc(dummies_predicted[:, 0])

        plt.plot(actual_values, label='Actual Close')
        plt.plot(predicted_values, label='Predicted Close')
        plt.xlabel('Day')
        plt.ylabel('Close')
        plt.title(title)
        plt.legend()
        plt.show()


    def plot_gradients_losses(self):
        figure, axis = plt.subplots(1, 2,figsize=(15, 5))
        axis[0].plot(self.gradients)
        axis[0].set_title('Fit in training')
        axis[0].set_xlabel('Steps (Iterations)')
        axis[0].set_ylabel('Mean gradient value')
      # Plot validation vs. training loss
        axis[1].plot(self.mean_losses, label='Training Loss')
        axis[1].plot(self.losses, label='Validation Loss', color='orange')
        axis[1].set_title('Validation vs. Training Loss')
        axis[1].set_xlabel('Epochs')
        axis[1].set_ylabel('Loss value (mean)')
        axis[1].legend()

        plt.show()

# %%
learning_rate = 0.001
num_epochs = 10
model = RNN(1, 50, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.066
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.0087879104539752
# Mean Absolute Error in testing: 0.09906671941280365

# %%
learning_rate = 0.001
num_epochs = 10
model = RNN(1, 50, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.044
# Batch 200, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.007339878939092159
# Mean Absolute Error in testing: 0.06873989850282669

# %%
learning_rate = 0.001
num_epochs = 10
model = RNN(1, 13, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.070
# Batch 200, Loss: 0.022
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.016
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.016
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.0064433058723807335
# Mean Absolute Error in testing: 0.10220301896333694

# %%
learning_rate = 0.001
num_epochs = 20
model = RNN(1, 13, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.074
# Batch 200, Loss: 0.010
#
# Val Loss: 0.092
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.087
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.085
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.081
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.074
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.064
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.057
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.054
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.052
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.046
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.045
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.040
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.035
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.035
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.0066304695792496204
# Mean Absolute Error in testing: 0.10958398133516312

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.008587515912950039
# Mean Absolute Error in testing: 0.04419126361608505

# %%
learning_rate = 0.001
num_epochs = 30
model = RNN(1, 15, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.084
# Batch 200, Loss: 0.009
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.000
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.021
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.0051717013120651245
# Mean Absolute Error in testing: 0.04256527125835419

# %%
learning_rate = 0.01
num_epochs = 30
model = RNN(1, 15, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.028
# Batch 200, Loss: 0.000
#
# Val Loss: 0.035
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.016
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.006582306697964668
# Mean Absolute Error in testing: 0.02651793695986271
